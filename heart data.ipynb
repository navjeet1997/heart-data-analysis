# %%
import numpy as np
import matplotlib as mp
import pandas as pa
import seaborn
# %matplotlib inline

# %%
df=pa.read_csv("Desktop/heart.csv")

# %%
df.head(20)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.boxplot(column='chol')
df.boxplot(column='oldpeak')

# %%
df.boxplot(column='chol')

# %%
fig = mp.pyplot.figure(figsize=(8,4))
temp1=df['cp'].value_counts()
ax1 = fig.add_subplot(121)
ax1.set_xlabel('cp')
ax1.set_ylabel('no of patients')

temp1.plot(kind='bar')

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
predictor =['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
target=['target']

# %%
params=[{'C':[.01,.1,1,10,.001,.0001]}]

# %%
clf = GridSearchCV(LogisticRegression(),params, cv=5,
                       scoring=metrics.make_scorer(metrics.accuracy_score))
clf.fit(X_train, y_train)
# Out:
# C:\Users\Asus\Anaconda2\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Asus\Anaconda2\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Asus\Anaconda2\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
def classification (model,predictor,target):
    model.fit(predictor,target)
    predictions=model.predict(predictor)
    accuracy = metrics.accuracy_score(predictions,target)
    print (accuracy)
    
    return model

# %%
print (clf.best_params_)
# Out:
# {'C': 0.1}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[predictor], df[target], test_size=0.2)

# %%
mo=classification(LogisticRegression(),X_train,y_train)
# Out:
# 0.8677685950413223
# C:\Users\Asus\Anaconda2\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X_train.head(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 118   46    0   1       105   204    0        1      172      0      0.0
# 130   54    0   2       160   201    0        1      163      0      0.0
# 258   62    0   0       150   244    0        1      154      1      1.4
# 11    48    0   2       130   275    0        1      139      0      0.2
# 191   58    1   0       128   216    0        0      131      1      2.2
# 43    53    0   0       130   264    0        0      143      0      0.4
# 160   56    1   1       120   240    0        1      169      0      0.0
# 36    54    0   2       135   304    1        1      170      0      0.0
# 142   42    0   2       120   209    0        1      173      0      0.0
# 49    53    0   0       138   234    0        0      160      0      0.0
#
#      slope  ca  thal
# 118      2   0     2
# 130      2   1     2
# 258      1   0     2
# 11       2   0     2
# 191      1   3     3
# 43       1   0     2
# ...

# %%
ar=mo.predict(X_test)
accuracy = metrics.accuracy_score(ar,y_test)
print (accuracy)
# Out:
# 0.819672131147541
